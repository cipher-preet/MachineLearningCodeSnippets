# %%
import pandas as pd
import requests

# %% [markdown]
# open csv in local machine

# %%
df = pd.read_csv('placement.csv')

df
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %% [markdown]
# opening csv file from URL

# %%
from io import StringIO

import requests

url='https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv'

data = requests.get(url).text

c = pd.read_csv(StringIO(data))

c.head()
# Out:
#     Country  Region
# 0   Algeria  AFRICA
# 1    Angola  AFRICA
# 2     Benin  AFRICA
# 3  Botswana  AFRICA
# 4   Burkina  AFRICA

# %% [markdown]
# whenever ypu are working with 'tsv' file you can use "sep paramenter"
#
# for example
#
# df = pd.read_csv('placement.csv', sep='\t')
# you can tell the code the it is seprated by tab not comas so result would be accurate.

# %% [markdown]
# index_col parameter
#
# basically it can remove default index of Pandas Provided, and add index what you are...
#
# example ->
#
# df = pd.read_csv('placement.csv', index_col='coloumn name which you want to be an index')

# %% [markdown]
# Header Parameter
#
# changes row into header

# %% [markdown]
# use_cols parameter
#
# filter the coloumn which you want

# %% [markdown]
# Squeeze Parameter

# %% [markdown]
# Skiprows/nrows Parameter
#
# skip the  rows

# %% [markdown]
# Encoding Parameters

# %% [markdown]
# skip bad lines
#
# when the data is diffect in rows or in colounms the this function will manage the data
#
# example df = pd.read_csv('placement.csv', index_col='coloumn name which you want to be an index', error_bad_lines=False)

# %% [markdown]
# dtypes parameter
#
# to change the datatype of coloumn or any data

# %% [markdown]
# Handling Data
#
# chang ethe dataType in "Datetype" type

# %% [markdown]
# Convertors
#
#
# apply the transformation on data

# %% [markdown]
# na_value Parameters

# %% [markdown]
# loading a huge dataset in chunks
#
# divide the datasets in chunks
#
# example -> chunksize=5000

# %%
#read JSON file in pandas

pd.read_json('test.json')
# Out:
#          id                                        ingredients
# 0     18009  [baking powder, eggs, all-purpose flour, raisi...
# 1     28583  [sugar, egg yolks, corn starch, cream of tarta...
# 2     41580  [sausage links, fennel bulb, fronds, olive oil...
# 3     29752  [meat cuts, file powder, smoked sausage, okra,...
# 4     35687  [ground black pepper, salt, sausage casings, l...
# ...     ...                                                ...
# 9939  30246  [large egg yolks, fresh lemon juice, sugar, bo...
# 9940  36028  [hot sauce, butter, sweet potatoes, adobo sauc...
# 9941  22339  [black pepper, salt, parmigiano reggiano chees...
# 9942  42525  [cheddar cheese, cayenne, paprika, plum tomato...
# 9943   1443  [cold water, olive oil, lime wedges, garlic cl...
#
# [9944 rows x 2 columns]

# %%
pd.read_json("https://dummyapi.online/api/movies")

#we can also fetch from URL
# Out:
#      id                                          movie  rating  \
# 0     1                       The Shawshank Redemption     9.2
# 1     2                                  The Godfather     9.2
# 2     3                                The Dark Knight     9.0
# 3     4                                   Pulp Fiction     8.9
# 4     5  The Lord of the Rings: The Return of the King     9.0
# ..  ...                                            ...     ...
# 95   96                                       Parasite     8.6
# 96   97                                   Little Women     7.8
# 97   98                                 Ford v Ferrari     8.1
# 98   99                                   The Irishman     7.8
# 99  100                                 Marriage Story     7.9
#
#                           image                               imdb_url
# 0          images/shawshank.jpg  https://www.imdb.com/title/tt0111161/
# ...

# %%
# lets try with sql database

# step I  ->  firstly we connect with "mysql.connector" libraray (this library can connect the paython to mysql database)

#step II -> conn = mysql.connector.connect(host='localhost',user='root',password='',database='world')


#step III -> df = pd.read_sql_query("SELECT * FROM countrylanguage",conn)

# %%
# try with API

res = requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1")

# %%
res.json()['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg',
#   'genre_ids': [18, 80],
#   'id': 278,
#   'original_language': 'en',
#   'original_title': 'The Shawshank Redemption',
#   'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#   'popularity': 174.522,
#   'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#   'release_date': '1994-09-23',
#   'title': 'The Shawshank Redemption',
#   'video': False,
#   'vote_average': 8.706,
#   'vote_count': 26775},
#  {'adult': False,
#   'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg',
#   'genre_ids': [18, 80],
#   'id': 238,
#   'original_language': 'en',
# ...

# %%
#convert the data into pandas data frame

# %%
pd.DataFrame(res.json()['results'])[["id","title","popularity","release_date"]]
# Out:
#         id                                          title  popularity  \
# 0      278                       The Shawshank Redemption     174.522
# 1      238                                  The Godfather     165.677
# 2      240                          The Godfather Part II      90.176
# 3      424                               Schindler's List     108.605
# 4      389                                   12 Angry Men      64.609
# 5      129                                  Spirited Away     115.254
# 6    19404                    Dilwale Dulhania Le Jayenge      47.936
# 7      155                                The Dark Knight     158.364
# 8   496243                                       Parasite      96.463
# 9      497                                 The Green Mile     135.171
# 10  372058                                     Your Name.      98.355
# 11     680                                   Pulp Fiction      96.758
# ...

# %%
dataf = pd.DataFrame()

dataf

# %%
for i in range(1,429):
    res = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    dataframe = pd.DataFrame(res.json()['results'])[["id","title","popularity","release_date"]]
    dataf = pd.concat([dataf,dataframe],ignore_index=True)

# %%
dataf
# Out:
#            id                      title  popularity release_date
# 0         278   The Shawshank Redemption     174.522   1994-09-23
# 1         238              The Godfather     165.677   1972-03-14
# 2         240      The Godfather Part II      90.176   1974-12-20
# 3         424           Schindler's List     108.605   1993-12-15
# 4         389               12 Angry Men      64.609   1957-04-10
# ...       ...                        ...         ...          ...
# 13815  385360      Billionaire Boys Club      13.856   2018-07-19
# 13816  230222                     Tarzan      17.680   2013-10-17
# 13817   59115     Quarantine 2: Terminal      15.068   2011-06-16
# 13818   23410                   The Thaw      13.461   2009-08-30
# 13819   12120  My Stepmother Is an Alien      18.924   1988-12-09
#
# [13820 rows x 4 columns]

# %%
#converts data sets into csv

dataf.to_csv("movies.csv")

# %%
# for data sets use "Rapidapi"  website

# %%
pd.read_csv("movies.csv")
# Out:
#        Unnamed: 0      id                      title  popularity release_date
# 0               0     278   The Shawshank Redemption     174.522   1994-09-23
# 1               1     238              The Godfather     165.677   1972-03-14
# 2               2     240      The Godfather Part II      90.176   1974-12-20
# 3               3     424           Schindler's List     108.605   1993-12-15
# 4               4     389               12 Angry Men      64.609   1957-04-10
# ...           ...     ...                        ...         ...          ...
# 13815       13815  385360      Billionaire Boys Club      13.856   2018-07-19
# 13816       13816  230222                     Tarzan      17.680   2013-10-17
# 13817       13817   59115     Quarantine 2: Terminal      15.068   2011-06-16
# 13818       13818   23410                   The Thaw      13.461   2009-08-30
# 13819       13819   12120  My Stepmother Is an Alien      18.924   1988-12-09
#
# [13820 rows x 5 columns]
